# %% [markdown]
# ## TYTAN tutorial チャレンジ問題1（スターバトル）
#
# 最終更新：2023年6月25日 by ビネクラ安田
#
# 取り組み方
#
# *   Google Colabで取り組む場合：ファイル＞ドライブにコピーを保存　<font color="red">※このファイルを直接編集しても保存されません</font>
# *   Jupyter Notebookに移す場合：ファイル＞ダウンロード＞.ipynbをダウンロード
#
# 参考リンク１
#
# *   [TYTANチュートリアル一覧](https://github.com/tytansdk/tytan_tutorial)
# *   [TYTANドキュメント](https://github.com/tytansdk/tytan/blob/main/document%20.md)

# %% [markdown]
# ### 問題
# スターバトル（Star Battle）と呼ばれるパズルを解いてください。
#
# 例題と解答はこちら。
#
# <div align="center">
# <img src="https://vigne-cla.com/wp-content/uploads/2023/05/21-22_1.png" width = 45%>
# </div>
#
# ＜パズルのルール＞
#
#
#
# *   ５つの領域に各１つだけ星を置く
# *   各行、各列には星が２つ以上あってはならない
# *   星の８近傍に他の星があってはならない
#
# ブラウザ上で遊んでみたいという方は [Puzzle Teamさんのサイト](https://ja.puzzle-star-battle.com/) をお試しください。
#
# それでは、本番の問題はこちらです。
#
# <div align="center">
# <img src="https://vigne-cla.com/wp-content/uploads/2023/05/21-22_2-300x300.png" width = 22%>
# </div>

# %% [markdown]
# ## コード

# %%
# !pip install git+https://github.com/tytansdk/tytan

# %%
from tytan import *
import numpy as np

#量子ビットを用意する


#条件設定
H = 0
H +=

#コンパイル
qubo, offset = Compile(H).get_qubo()
print(f'offset\n{offset}')

#サンプラー選択
solver = sampler.SASampler()

#サンプリング
result = solver.run(qubo, shots=100) #shots=500, 1000...

#上位5件
for r in result[:5]:
    print(r)
