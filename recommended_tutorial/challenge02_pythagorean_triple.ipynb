# %% [markdown]
# ## TYTAN tutorial チャレンジ問題2（ピタゴラス数）
#
# 最終更新：2023年6月25日 by ビネクラ安田
#
# 問題提供：derwind（Discord ID: derwind#4626）
#
# 取り組み方
#
# *   Google Colabで取り組む場合：ファイル＞ドライブにコピーを保存　<font color="red">※このファイルを直接編集しても保存されません</font>
# *   Jupyter Notebookに移す場合：ファイル＞ダウンロード＞.ipynbをダウンロード
#
# 参考リンク１
#
# *   [TYTANチュートリアル一覧](https://github.com/tytansdk/tytan_tutorial)
# *   [TYTANドキュメント](https://github.com/tytansdk/tytan/blob/main/document%20.md)

# %% [markdown]
# ### 問題
# ピタゴラス数は、x<sup>2</sup> + y<sup>2</sup> = z<sup>2</sup> を満たす自然数(x, y, z)の組です。参考→ [Wikipedia「ピタゴラス数」](https://ja.wikipedia.org/wiki/%E3%83%94%E3%82%BF%E3%82%B4%E3%83%A9%E3%82%B9%E6%95%B0)
#
# (x, y, z)ともに20未満のピタゴラス数（原始ピタゴラス数）をすべて求めてください。
#
# 想定される回答は、原始ピタゴラス数：(3, 4, 5), (5, 12, 13), (8, 15, 17) ですが、(3, 4, 5)の倍数である：(6, 8, 10), (9, 12, 15) を含んでも構いません。また、xとyは入れ変わっても差し支えありません。

# %% [markdown]
# ## コード

# %%
# !pip install git+https://github.com/tytansdk/tytan

# %%
from tytan import *
import numpy as np

#量子ビットを用意する


#条件設定
H = 0
H +=

#コンパイル
qubo, offset = Compile(H).get_qubo()
print(f'offset\n{offset}')

#サンプラー選択
solver = sampler.SASampler()

#サンプリング
result = solver.run(qubo, shots=100) #shots=500, 1000...

#上位5件
for r in result[:5]:
    print(r)
