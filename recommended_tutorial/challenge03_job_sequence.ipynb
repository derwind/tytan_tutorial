# %% [markdown]
# ## TYTAN tutorial チャレンジ問題3（ジョブシーケンス問題）
#
# 最終更新：2023年6月28日 by ビネクラ安田
#
# 取り組み方
#
# *   Google Colabで取り組む場合：ファイル＞ドライブにコピーを保存　<font color="red">※このファイルを直接編集しても保存されません</font>
# *   Jupyter Notebookに移す場合：ファイル＞ダウンロード＞.ipynbをダウンロード
#
# 参考リンク１
#
# *   [TYTANチュートリアル一覧](https://github.com/tytansdk/tytan_tutorial)
# *   [TYTANドキュメント](https://github.com/tytansdk/tytan/blob/main/document%20.md)

# %% [markdown]
# ### 問題
# ポケモンセンターにはポケモンを回復させる「装置」が3台あります。装置には一度に一匹だけポケモンを入れることができ、1分毎にHPを1回復させます。いま、ダメージを負ったポケモンが10匹来院しました。彼らを3台の装置に適当に割り振って、できるだけ短い時間で全員を回復させたいです。全員が回復するまでにかかる最小の時間を求めてください。
#
# 各ポケモンのダメージ量（＝回復すべきHP量）<br>
# 17, 19, 25, 29, 30, 57, 60, 67, 97, 107
#
# ＜ここに図が入る＞
#
# 装置に入ったポケモンは全回復するまで取り出したり他の装置に移したりすることはできません。また、ポケモンの入れ替え時間はゼロとします。全員が回復するまでにかかる時間とは、一番遅いポケモンの回復が完了するまでの時間のことです。

# %% [markdown]
# ## コード

# %%
# !pip install git+https://github.com/tytansdk/tytan

# %%
from tytan import *
import numpy as np

#量子ビットを用意する


#条件設定
H = 0
H +=

#コンパイル
qubo, offset = Compile(H).get_qubo()
print(f'offset\n{offset}')

#サンプラー選択
solver = sampler.SASampler()

#サンプリング
result = solver.run(qubo, shots=100) #shots=500, 1000...

#上位5件
for r in result[:5]:
    print(r)
