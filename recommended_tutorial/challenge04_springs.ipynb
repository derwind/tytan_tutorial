# %% [markdown]
# ## TYTAN tutorial 実力テスト4（ばねにはたらく力）
#
# 最終更新：2023年7月3日 by ビネクラ安田
#
# 問題提供：derwind（Discord ID: derwind#4626）
#
# 取り組み方
#
# *   Google Colabで取り組む場合：ファイル＞ドライブにコピーを保存　<font color="red">※このファイルを直接編集しても保存されません</font>
# *   Jupyter Notebookに移す場合：ファイル＞ダウンロード＞.ipynbをダウンロード
#
# 参考リンク１
#
# *   [TYTANチュートリアル一覧](https://github.com/tytansdk/tytan_tutorial)
# *   [TYTANドキュメント](https://github.com/tytansdk/tytan/blob/main/document%20.md)

# %% [markdown]
# ### 問１
# 自然長が1、ばね定数が1の軽いばねが2個ある。
#
# <div align="center">
# <img src="https://vigne-cla.com/wp-content/uploads/2023/07/21-32_1.png" width = 35%>
# </div>
#
# この２個のばねを直列につなげ、幅3の壁の隙間にひっかけた。
#
# <div align="center">
# <img src="https://vigne-cla.com/wp-content/uploads/2023/07/21-32_2.png" width = 35%>
# </div>
#
# このときの各ばねの長さを求めよ。なお、ばね定数 $k$ のばねが自然長から長さ $x$ だけ伸縮したときの弾性力は $kx$ である。

# %% [markdown]
# ## コード

# %%
# !pip install git+https://github.com/tytansdk/tytan

# %%
from tytan import *
import numpy as np

#量子ビットを用意する


#条件設定
H = 0
H +=

#コンパイル
qubo, offset = Compile(H).get_qubo()
print(f'offset\n{offset}')

#サンプラー選択
solver = sampler.SASampler()

#サンプリング
result = solver.run(qubo, shots=100) #shots=500, 1000...

#上位5件
for r in result[:5]:
    print(r)

# %% [markdown]
# ### 問２
# 自然長が1の軽いばねが4個ある。それぞれのばね定数は1, 2, 3, 4である。
#
# <div align="center">
# <img src="https://vigne-cla.com/wp-content/uploads/2023/07/21-32_3.png" width = 35%>
# </div>
#
# この4個のばねを直列につなげ、幅5の壁の隙間にひっかけた。
#
# <div align="center">
# <img src="https://vigne-cla.com/wp-content/uploads/2023/07/21-32_4-1024x227.png" width = 60%>
# </div>
#
# このときの各ばねの長さを小数点以下3桁まで求めよ。

# %%
from tytan import *
import numpy as np

#量子ビットを用意する


#条件設定
H = 0
H +=

#コンパイル
qubo, offset = Compile(H).get_qubo()
print(f'offset\n{offset}')

#サンプラー選択
solver = sampler.SASampler()

#サンプリング
result = solver.run(qubo, shots=100) #shots=500, 1000...

#上位5件
for r in result[:5]:
    print(r)
